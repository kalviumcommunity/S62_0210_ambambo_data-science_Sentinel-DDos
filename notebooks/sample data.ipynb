# %%
import pandas as pd

clean = pd.read_csv("../data/processed/cic_final_clean.csv", low_memory=False)
behavior = pd.read_csv("../data/processed/cic_final_behavior.csv", low_memory=False)

# Take 5000 rows random sample
clean_sample = clean.sample(5000, random_state=42)
behavior_sample = behavior.sample(5000, random_state=42)

# Save them
clean_sample.to_csv("../data/processed/clean_sample.csv", index=False)
behavior_sample.to_csv("../data/processed/behavior_sample.csv", index=False)
