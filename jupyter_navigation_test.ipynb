# %%
print("Milestone working correctly")
# Out:
# Milestone working correctly

# %% [markdown]
# # Understanding Code and Markdown Cells

# %% [markdown]
# ## Purpose
#
# This notebook demonstrates the difference between Code cells and Markdown cells.
# Code cells execute Python.
# Markdown cells explain the logic and reasoning.

# %%
x = 10
y = 20
print(f"The sum of {x} and {y} is {x + y}.")
# Out:
# The sum of 10 and 20 is 30.

# %% [markdown]
# ### Explanation of the Above Code
#
# We created two variables, x and y.
# Then we added them together.
# The output shows the result of the addition.

# %%
name = "Issac"
print("Hello", name)
# Out:
# Hello Issac

# %% [markdown]
# ### Explanation
#
# This code stores a name in a variable and prints a greeting message.
# The print() function displays output to the screen.
