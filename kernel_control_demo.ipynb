# %%
x = 10
print("Value of x:", x)
# Out:
# Value of x: 10

# %%
y = x + 5
print("Value of y:", y)
# Out:
# Value of y: 15

# %%
import time
for i in range(10):
    print("Running...", i)
    time.sleep(1)
# Out:
# Running... 0
# Running... 1
# Running... 2
# Running... 3
# Running... 4
# Running... 5
# Running... 6
# Running... 7
# Running... 8
# Running... 9

# %%
print(x)
# Out:
# 10

# %%
print(x)
# Out:
# 10
