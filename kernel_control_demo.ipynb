# %% [markdown]
# # Kernel Control Demonstration
#
# This notebook demonstrates:
# - Intentional cell execution
# - Interrupting a running cell
# - Restarting the kernel
# - Clean state management

# %%
x = 10
print("Value of x:", x)
# Out:
# Value of x: 10

# %%
y = x + 5
print("Value of y:", y)
# Out:
# Value of y: 15

# %%
import time
for i in range(10):
    print("Running...", i)
    time.sleep(1)
# Out:
# Running... 0
# Running... 1
# Running... 2
# Running... 3
# Running... 4
# Running... 5
# Running... 6
# Running... 7
# Running... 8
# Running... 9

# %%
print(x)
# Out:
# 10

# %% [markdown]
# ## Demonstrating Kernel State Retention
# The kernel stores variables in memory between cell executions.
#
# ## Demonstrating Interrupt
# This cell runs slowly so that we can interrupt it safely.
# Interrupting stops execution but does not clear memory.
#
# ## Demonstrating Kernel Restart
# Restarting the kernel clears all variables and resets the notebook state.

# %%
print(x)
# Out:
# 10

# %% [markdown]
# ## Best Practice
#
# Before submitting a notebook, always use:
# Kernel → Restart & Run All
#
# This ensures:
# - Correct execution order
# - No hidden kernel state
# - Reproducibility for others
